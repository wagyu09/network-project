# %%
import pandas as pd
df = pd.read_csv('final_summary_report.csv')

# %%
df
# Out:
#       Portfolio  Avg. Return  Avg. Volatility  Avg. Sharpe Ratio  \
# 0  최소 중심성 포트폴리오       0.0327           0.2142             0.0574
# 1  최대 중심성 포트폴리오       0.0360           0.1940             0.0560
# 2      랜덤 포트폴리오       0.0498           0.2184             0.0668
#
#    Avg. Max Drawdown  Volatility Wins  Sharpe Ratio Wins  MDD Wins
# 0            -0.1043                9                 10         9
# 1            -0.0887               11                  6        14
# 2            -0.1002               10                 14         7
